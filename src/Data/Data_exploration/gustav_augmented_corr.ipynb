# %%
# %load_ext autoreload
#To update the imported files
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload
import os
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import classification_report, accuracy_score
from sklearn.metrics import mean_absolute_error
from utilities_EDA import *
import seaborn as sns
# %matplotlib inline

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)

# %%
import sys
sys.path.insert(0, '../../Models')
from constants import *
from utilities import *
from constants_augmented  import *

# %%
#subset_X_observed_a, y_a =  resize_training_data(subset_X_observed_a.copy(), y_a.copy())
#subset_X_observed_b, y_b =  resize_training_data(subset_X_observed_b.copy(), y_b.copy())
#subset_X_observed_c, y_c =  resize_training_data(subset_X_observed_c.copy(), y_c.copy())

# %%
correlation_plot(clean_X_data(subset_X_observed_a),y_a)
# Out:
# C:\Users\Gustav\Documents\maskinlaering\ML_prosject\TDT4173-ML-task\src\Data\Data_exploration\utilities_EDA.py:31: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = correlation_df.corr()

# %%
def change_scale(x):
    #if isinstance(x, (int, float)):  # Check if x is numeric
    #    return np.log(x) if x > 0 else x
    return x

X_train_observed_a["sum"] = X_train_observed_a['direct_rad:W'] * X_train_observed_a['direct_rad_1h:J']
correlation_df = pd.DataFrame({
    "observed_a":correlation(clean_X_data(X_train_observed_a.map(change_scale)),train_a)["pv_measurement"],
    "observed_b":correlation(clean_X_data(X_train_observed_b.map(change_scale)),train_b)["pv_measurement"],
    "observed_c":correlation(clean_X_data(X_train_observed_c.map(change_scale)),train_c)["pv_measurement"],
    "estimated_a":correlation(clean_X_data(X_train_estimated_a.map(change_scale)),train_a)["pv_measurement"],
    "estimated_b":correlation(clean_X_data(X_train_estimated_b.map(change_scale)),train_b)["pv_measurement"],
    "estimated_c":correlation(clean_X_data(X_train_estimated_c.map(change_scale)),train_c)["pv_measurement"],
})

# %%
correlation_df
# Out:
#                                 observed_a  observed_b  observed_c  \
# absolute_humidity_2m:gm3          0.229924    0.326308    0.320863
# air_density_2m:kgm3              -0.364369   -0.376864   -0.427060
# ceiling_height_agl:m              0.177534    0.175426    0.190529
# clear_sky_energy_1h:J             0.781647    0.774912    0.843075
# clear_sky_rad:W                   0.803990    0.793606    0.857913
# cloud_base_agl:m                  0.163880    0.202945    0.140562
# date_forecast                     0.023750   -0.077734   -0.006741
# dew_or_rime:idx                  -0.065608   -0.022469    0.014944
# dew_point_2m:K                    0.244038    0.329227    0.328974
# diffuse_rad:W                     0.705704    0.684099    0.732888
# diffuse_rad_1h:J                  0.689930    0.672749    0.722412
# direct_rad:W                      0.853315    0.804214    0.865623
# direct_rad_1h:J                   0.828454    0.784503    0.853125
# effective_cloud_cover:p          -0.210716   -0.169106   -0.149893
# elevation:m                            NaN         NaN         NaN
# fresh_snow_12h:cm                -0.047860   -0.063852   -0.063853
# fresh_snow_1h:cm                 -0.032443   -0.039116   -0.042789
# fresh_snow_24h:cm                -0.063604   -0.076897   -0.080759
# fresh_snow_3h:cm                 -0.040175   -0.048134   -0.050336
# fresh_snow_6h:cm                 -0.045782   -0.055071   -0.057922
# is_day:idx                        0.537770    0.474955    0.507588
# is_in_shadow:idx                 -0.573644   -0.509134   -0.588678
# msl_pressure:hPa                  0.182269    0.188471    0.196033
# precip_5min:mm                   -0.060665   -0.043243   -0.049347
# precip_type_5min:idx             -0.087411   -0.072053   -0.075521
# pressure_100m:hPa                 0.182301    0.197997    0.199867
# pressure_50m:hPa                  0.177477    0.192404    0.193905
# prob_rime:p                      -0.040825   -0.022675   -0.113755
# pv_measurement                    1.000000    1.000000    1.000000
# rain_water:kgm2                  -0.081230   -0.035745   -0.050864
# relative_humidity_1000hPa:p      -0.374446   -0.336559   -0.366973
# sfc_pressure:hPa                  0.172617    0.186855    0.187903
# snow_density:kgm3                      NaN         NaN         NaN
# snow_depth:cm                    -0.057964   -0.089373   -0.094993
# snow_drift:idx                         NaN   -0.004265         NaN
# snow_melt_10min:mm               -0.018081   -0.025271   -0.041738
# snow_water:kgm2                  -0.130121   -0.109181   -0.112270
# sum                               0.732992         NaN         NaN
# sun_azimuth:d                    -0.064520   -0.052483   -0.037513
# sun_elevation:d                   0.691070    0.656581    0.685768
# super_cooled_liquid_water:kgm2   -0.121977   -0.089780   -0.075746
# t_1000hPa:K                       0.338399    0.422907    0.430839
# time                              0.023750   -0.077734   -0.006741
# total_cloud_cover:p              -0.179321   -0.138248   -0.117930
# visibility:m                      0.242822    0.133719    0.163754
# wind_speed_10m:ms                -0.089271   -0.096226   -0.080156
# wind_speed_u_10m:ms              -0.068022   -0.054186   -0.037359
# wind_speed_v_10m:ms              -0.265496   -0.261321   -0.314944
# wind_speed_w_1000hPa:ms          -0.006872   -0.006860    0.018155
#
#                                 estimated_a  estimated_b  estimated_c
# absolute_humidity_2m:gm3           0.041681     0.058680     0.105518
# air_density_2m:kgm3               -0.133887    -0.085192    -0.223042
# ceiling_height_agl:m               0.097077     0.057785     0.070167
# clear_sky_energy_1h:J              0.759709     0.803965     0.828625
# clear_sky_rad:W                    0.787613     0.831445     0.816881
# cloud_base_agl:m                   0.066471     0.045384     0.044497
# date_forecast                      0.339208     0.366957     0.363656
# dew_or_rime:idx                   -0.020751    -0.035938     0.036820
# dew_point_2m:K                     0.043904     0.066860     0.122715
# diffuse_rad:W                      0.622477     0.649865     0.659043
# diffuse_rad_1h:J                   0.605870     0.637746     0.673282
# direct_rad:W                       0.881677     0.853044     0.826789
# direct_rad_1h:J                    0.847495     0.819666     0.837093
# effective_cloud_cover:p           -0.282059    -0.207598    -0.172603
# elevation:m                             NaN          NaN          NaN
# fresh_snow_12h:cm                 -0.085648    -0.082548    -0.079468
# fresh_snow_1h:cm                  -0.061070    -0.050659    -0.057807
# fresh_snow_24h:cm                 -0.097157    -0.097484    -0.065276
# fresh_snow_3h:cm                  -0.069734    -0.061975    -0.071193
# fresh_snow_6h:cm                  -0.074362    -0.069707    -0.080109
# is_day:idx                         0.517589     0.464203     0.476934
# is_in_shadow:idx                  -0.562579    -0.502674    -0.557879
# msl_pressure:hPa                   0.209549     0.195301     0.199730
# precip_5min:mm                    -0.052488    -0.048418    -0.057771
# precip_type_5min:idx              -0.053024    -0.044529    -0.045985
# pressure_100m:hPa                  0.206754     0.197321     0.198338
# pressure_50m:hPa                   0.204993     0.195667     0.195504
# prob_rime:p                       -0.034744    -0.011161    -0.110349
# pv_measurement                     1.000000     1.000000     1.000000
# rain_water:kgm2                   -0.051069    -0.052087    -0.057589
# relative_humidity_1000hPa:p       -0.355010    -0.305529    -0.347783
# sfc_pressure:hPa                   0.203217     0.193948     0.192841
# snow_density:kgm3                       NaN          NaN          NaN
# snow_depth:cm                     -0.057422    -0.051167    -0.042046
# snow_drift:idx                          NaN          NaN          NaN
# snow_melt_10min:mm                 0.026938     0.004211    -0.012595
# snow_water:kgm2                   -0.091693    -0.067772    -0.066939
# sum                                     NaN          NaN          NaN
# sun_azimuth:d                     -0.049054    -0.045398     0.029689
# sun_elevation:d                    0.580583     0.582336     0.594574
# super_cooled_liquid_water:kgm2    -0.091427    -0.084773    -0.100142
# t_1000hPa:K                        0.131462     0.156718     0.226291
# time                               0.339208     0.366957     0.363656
# total_cloud_cover:p               -0.279154    -0.203857    -0.170901
# visibility:m                       0.126445     0.012875     0.041083
# wind_speed_10m:ms                 -0.073267    -0.059354    -0.034430
# wind_speed_u_10m:ms               -0.076762    -0.056676    -0.062777
# wind_speed_v_10m:ms               -0.164970    -0.142147    -0.215448
# wind_speed_w_1000hPa:ms                 NaN          NaN    -0.077735

# %%
snittverdier = correlation_df.mean(axis = 1)
snittverdier = snittverdier.abs()
snittverdier = snittverdier.sort_values(ascending=False)

# %%
(snittverdier)
# Out:
# pv_measurement                    1.000000
# direct_rad:W                      0.847444
# direct_rad_1h:J                   0.828389
# clear_sky_rad:W                   0.815241
# clear_sky_energy_1h:J             0.798656
# sum                               0.732992
# diffuse_rad:W                     0.675679
# diffuse_rad_1h:J                  0.666998
# sun_elevation:d                   0.631819
# is_in_shadow:idx                  0.549098
# is_day:idx                        0.496506
# relative_humidity_1000hPa:p       0.347717
# t_1000hPa:K                       0.284436
# air_density_2m:kgm3               0.268402
# wind_speed_v_10m:ms               0.227387
# effective_cloud_cover:p           0.198662
# pressure_100m:hPa                 0.197096
# msl_pressure:hPa                  0.195226
# pressure_50m:hPa                  0.193325
# sfc_pressure:hPa                  0.189563
# dew_point_2m:K                    0.189287
# total_cloud_cover:p               0.181568
# absolute_humidity_2m:gm3          0.180496
# time                              0.168183
# date_forecast                     0.168183
# ceiling_height_agl:m              0.128086
# visibility:m                      0.120116
# cloud_base_agl:m                  0.110623
# snow_water:kgm2                   0.096329
# super_cooled_liquid_water:kgm2    0.093974
# fresh_snow_24h:cm                 0.080196
# wind_speed_10m:ms                 0.072117
# fresh_snow_12h:cm                 0.070538
# snow_depth:cm                     0.065494
# fresh_snow_6h:cm                  0.063826
# precip_type_5min:idx              0.063087
# wind_speed_u_10m:ms               0.059297
# fresh_snow_3h:cm                  0.056924
# prob_rime:p                       0.055585
# rain_water:kgm2                   0.054764
# precip_5min:mm                    0.051989
# fresh_snow_1h:cm                  0.047314
# sun_azimuth:d                     0.036546
# wind_speed_w_1000hPa:ms           0.018328
# dew_or_rime:idx                   0.015500
# snow_melt_10min:mm                0.011089
# snow_drift:idx                    0.004265
# elevation:m                            NaN
# snow_density:kgm3                      NaN
# dtype: float64

# %%
log = snittverdier

# %%
qubr = snittverdier

# %%
sqr = snittverdier

# %%
sqrt = snittverdier

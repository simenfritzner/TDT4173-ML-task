# %%
# %load_ext autoreload
#To update the imported files

# %%
# %autoreload
import os
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import classification_report, accuracy_score
from sklearn.metrics import mean_absolute_error
from utilities_EDA import *
import seaborn as sns
# %matplotlib inline

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)

# %%
#Loading the y-paramter from file, might be changed to y_a etc.
train_a = pd.read_parquet('../Data_and_task/A/train_targets.parquet')
train_b = pd.read_parquet('../Data_and_task/B/train_targets.parquet')
train_c = pd.read_parquet('../Data_and_task/C/train_targets.parquet')

# %%
#Loading estimated/forecasted training_weather from file
X_train_estimated_a = pd.read_parquet('../Data_and_task/A/X_train_estimated.parquet')
X_train_estimated_b = pd.read_parquet('../Data_and_task/B/X_train_estimated.parquet')
X_train_estimated_c = pd.read_parquet('../Data_and_task/C/X_train_estimated.parquet')

# %%
#Loading observed weather from file
X_train_observed_a = pd.read_parquet('../Data_and_task/A/X_train_observed.parquet')
X_train_observed_b = pd.read_parquet('../Data_and_task/B/X_train_observed.parquet')
X_train_observed_c = pd.read_parquet('../Data_and_task/C/X_train_observed.parquet')

# %%
#Loading estimated/forecasted test_weather from file
X_test_estimated_a = pd.read_parquet('../Data_and_task/A/X_test_estimated.parquet')
X_test_estimated_b = pd.read_parquet('../Data_and_task/B/X_test_estimated.parquet')
X_test_estimated_c = pd.read_parquet('../Data_and_task/C/X_test_estimated.parquet')

# %%
#Fjernen kvarter-radene og fjerner "date_calc" kolonnen hvis den finnes
X_train_observed_a_clean = clean_X_data(X_train_observed_a)

# %%
correlation_plot(clean_X_data(X_train_observed_a),train_a)

# %%
def change_scale(x):
    if isinstance(x, (int, float)):  # Check if x is numeric
        return np.log(x) if x > 0 else x
    return x

X_train_observed_a["sum"] = X_train_observed_a['direct_rad:W'] * X_train_observed_a['direct_rad_1h:J']
correlation_df = pd.DataFrame({
    "observed_a":correlation(clean_X_data(X_train_observed_a.map(change_scale)),train_a)["pv_measurement"],
    "observed_b":correlation(clean_X_data(X_train_observed_b.map(change_scale)),train_b)["pv_measurement"],
    "observed_c":correlation(clean_X_data(X_train_observed_c.map(change_scale)),train_c)["pv_measurement"],
    "estimated_a":correlation(clean_X_data(X_train_estimated_a.map(change_scale)),train_a)["pv_measurement"],
    "estimated_b":correlation(clean_X_data(X_train_estimated_b.map(change_scale)),train_b)["pv_measurement"],
    "estimated_c":correlation(clean_X_data(X_train_estimated_c.map(change_scale)),train_c)["pv_measurement"],
})

# %%
correlation_df
# Out:
#                                 observed_a  observed_b  observed_c  \
# date_forecast                     0.023750   -0.077734   -0.006741
# absolute_humidity_2m:gm3          0.227983    0.313454    0.307623
# air_density_2m:kgm3              -0.368548   -0.380652   -0.433500
# ceiling_height_agl:m              0.172150    0.189144    0.167509
# clear_sky_energy_1h:J             0.588552    0.529199    0.565048
# clear_sky_rad:W                   0.690481    0.628433    0.675174
# cloud_base_agl:m                  0.157463    0.196640    0.113140
# dew_or_rime:idx                   0.046691    0.025764    0.136977
# dew_point_2m:K                    0.243332    0.327824    0.327283
# diffuse_rad:W                     0.674371    0.608458    0.652814
# diffuse_rad_1h:J                  0.567154    0.506985    0.540260
# direct_rad:W                      0.797696    0.708531    0.766989
# direct_rad_1h:J                   0.674445    0.598168    0.657402
# effective_cloud_cover:p          -0.155042   -0.124696   -0.099772
# elevation:m                            NaN         NaN         NaN
# fresh_snow_12h:cm                -0.012986   -0.018714   -0.023400
# fresh_snow_1h:cm                  0.026763    0.037061    0.036110
# fresh_snow_24h:cm                -0.028457   -0.032778   -0.055207
# fresh_snow_3h:cm                  0.011164    0.015678    0.014646
# fresh_snow_6h:cm                 -0.004608   -0.002815   -0.006295
# is_day:idx                             NaN         NaN         NaN
# is_in_shadow:idx                       NaN         NaN         NaN
# msl_pressure:hPa                  0.182339    0.188789    0.196100
# precip_5min:mm                    0.078118    0.067482    0.073795
# precip_type_5min:idx             -0.056577   -0.059207   -0.059113
# pressure_100m:hPa                 0.182363    0.198235    0.199897
# pressure_50m:hPa                  0.177584    0.192691    0.193995
# prob_rime:p                      -0.045930   -0.025908   -0.132476
# rain_water:kgm2                   0.088161    0.037742    0.052412
# relative_humidity_1000hPa:p      -0.376347   -0.343036   -0.379592
# sfc_pressure:hPa                  0.172770    0.187189    0.188054
# snow_density:kgm3                      NaN         NaN         NaN
# snow_depth:cm                    -0.036606   -0.089954   -0.072774
# snow_drift:idx                         NaN         NaN         NaN
# snow_melt_10min:mm                0.020593    0.035402    0.051982
# snow_water:kgm2                   0.133425    0.118837    0.109882
# sun_azimuth:d                     0.096803    0.070641    0.092031
# sun_elevation:d                   0.428240    0.394131    0.404495
# super_cooled_liquid_water:kgm2    0.097478    0.064302    0.039080
# t_1000hPa:K                       0.336783    0.420963    0.428081
# total_cloud_cover:p              -0.133165   -0.104588   -0.079848
# visibility:m                      0.197664    0.118652    0.131317
# wind_speed_10m:ms                -0.099169   -0.105816   -0.078346
# wind_speed_u_10m:ms              -0.051422   -0.033251   -0.023964
# wind_speed_v_10m:ms              -0.229322   -0.223392   -0.294805
# wind_speed_w_1000hPa:ms           0.006872    0.006860   -0.004892
# time                              0.023750   -0.077734   -0.006741
# pv_measurement                    1.000000    1.000000    1.000000
#
#                                 estimated_a  estimated_b  estimated_c
# date_forecast                      0.339208     0.366957     0.363656
# absolute_humidity_2m:gm3           0.039572     0.059631     0.110745
# air_density_2m:kgm3               -0.133237    -0.084376    -0.223054
# ceiling_height_agl:m               0.050711     0.026267     0.077969
# clear_sky_energy_1h:J              0.554456     0.511984     0.529311
# clear_sky_rad:W                    0.665175     0.625557     0.628765
# cloud_base_agl:m                   0.033014     0.022287     0.068417
# dew_or_rime:idx                    0.045556     0.021165     0.129703
# dew_point_2m:K                     0.043454     0.066594     0.122536
# diffuse_rad:W                      0.626151     0.586816     0.596812
# diffuse_rad_1h:J                   0.527434     0.484674     0.503187
# direct_rad:W                       0.779757     0.700441     0.705865
# direct_rad_1h:J                    0.644801     0.584133     0.629851
# effective_cloud_cover:p           -0.284457    -0.190841    -0.145270
# elevation:m                             NaN          NaN          NaN
# fresh_snow_12h:cm                 -0.058060    -0.046952    -0.033880
# fresh_snow_1h:cm                   0.055235     0.047393     0.055583
# fresh_snow_24h:cm                 -0.089356    -0.066950    -0.022205
# fresh_snow_3h:cm                   0.022602     0.026642     0.012386
# fresh_snow_6h:cm                  -0.004417     0.000675    -0.016475
# is_day:idx                              NaN          NaN          NaN
# is_in_shadow:idx                        NaN          NaN          NaN
# msl_pressure:hPa                   0.209141     0.194982     0.199424
# precip_5min:mm                     0.056428     0.048257     0.053892
# precip_type_5min:idx              -0.039099    -0.028759    -0.020338
# pressure_100m:hPa                  0.206370     0.196969     0.198035
# pressure_50m:hPa                   0.204628     0.195340     0.195238
# prob_rime:p                       -0.049228    -0.014552    -0.131740
# rain_water:kgm2                    0.056460     0.057735     0.062633
# relative_humidity_1000hPa:p       -0.374316    -0.314395    -0.355647
# sfc_pressure:hPa                   0.202872     0.193644     0.192609
# snow_density:kgm3                       NaN          NaN          NaN
# snow_depth:cm                     -0.032820    -0.026311     0.042710
# snow_drift:idx                          NaN          NaN          NaN
# snow_melt_10min:mm                -0.018891     0.012141     0.021664
# snow_water:kgm2                    0.116717     0.099760     0.083360
# sun_azimuth:d                      0.063941     0.062883     0.120306
# sun_elevation:d                    0.392507     0.364410     0.374277
# super_cooled_liquid_water:kgm2     0.096230     0.078732     0.095211
# t_1000hPa:K                        0.131026     0.156318     0.225680
# total_cloud_cover:p               -0.274386    -0.183072    -0.138187
# visibility:m                       0.124307     0.045095     0.073078
# wind_speed_10m:ms                 -0.124892    -0.113698    -0.067325
# wind_speed_u_10m:ms               -0.069033    -0.051533    -0.066352
# wind_speed_v_10m:ms               -0.136499    -0.119217    -0.208833
# wind_speed_w_1000hPa:ms                 NaN          NaN    -0.003842
# time                               0.339208     0.366957     0.363656
# pv_measurement                     1.000000     1.000000     1.000000

# %%
snittverdier = correlation_df.mean(axis = 1)
snittverdier = snittverdier.abs()
snittverdier = snittverdier.sort_values(ascending=False)

# %%
(snittverdier)
# Out:
# pv_measurement                    1.000000
# direct_rad:W                      0.743213
# clear_sky_rad:W                   0.652264
# direct_rad_1h:J                   0.631467
# diffuse_rad:W                     0.624237
# clear_sky_energy_1h:J             0.546425
# diffuse_rad_1h:J                  0.521616
# sun_elevation:d                   0.393010
# relative_humidity_1000hPa:p       0.357222
# t_1000hPa:K                       0.283142
# air_density_2m:kgm3               0.270561
# wind_speed_v_10m:ms               0.202011
# pressure_100m:hPa                 0.196978
# msl_pressure:hPa                  0.195129
# pressure_50m:hPa                  0.193246
# sfc_pressure:hPa                  0.189523
# dew_point_2m:K                    0.188504
# absolute_humidity_2m:gm3          0.176501
# time                              0.168183
# date_forecast                     0.168183
# effective_cloud_cover:p           0.166680
# total_cloud_cover:p               0.152208
# visibility:m                      0.115019
# ceiling_height_agl:m              0.113958
# snow_water:kgm2                   0.110330
# cloud_base_agl:m                  0.098493
# wind_speed_10m:ms                 0.098208
# sun_azimuth:d                     0.084434
# super_cooled_liquid_water:kgm2    0.078505
# dew_or_rime:idx                   0.067643
# prob_rime:p                       0.066639
# precip_5min:mm                    0.062995
# rain_water:kgm2                   0.059191
# wind_speed_u_10m:ms               0.049259
# fresh_snow_24h:cm                 0.049159
# precip_type_5min:idx              0.043849
# fresh_snow_1h:cm                  0.043024
# snow_depth:cm                     0.035959
# fresh_snow_12h:cm                 0.032332
# snow_melt_10min:mm                0.020482
# fresh_snow_3h:cm                  0.017186
# fresh_snow_6h:cm                  0.005656
# wind_speed_w_1000hPa:ms           0.001249
# elevation:m                            NaN
# is_day:idx                             NaN
# is_in_shadow:idx                       NaN
# snow_density:kgm3                      NaN
# snow_drift:idx                         NaN
# dtype: float64

# %%
log = snittverdier

# %%
qubr = snittverdier

# %%
sqr = snittverdier

# %%
sqrt = snittverdier
